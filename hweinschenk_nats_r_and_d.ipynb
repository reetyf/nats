# %% [markdown]
# # Hailey Weinschenk - WSH - R&D Analyst  Questionnaire - March, 2023

# %% [markdown]
# # 1.

# %% [markdown]
# **After the season has ended, you are told a 90-win team played a home game against an 80-win
# team. Without additional information about the two teams, what is the probability that the
# home team won?**

# %%
ninety_win_team = 90/162
eighty_win_team = 80/162

ninety_win_team, eighty_win_team
# Out:
# (0.5555555555555556, 0.49382716049382713)

# %% [markdown]
# # 2.

# %% [markdown]
# **Suppose you are starting an MLB team from scratch and can pick from the following cores of
# players including their current contracts. Which would you pick and why?**
#
# **A. Vladimir Guerrero Jr., Bo Bichette, and Alek Manoah**
#
# **B. Jose Ramirez, Andres Gimenez, and Steven Kwan**

# %% [markdown]
# Before anything else, it must be said that a GM or team president cannot go wrong with either of these cores, which are both teeming with talent and youth. It is for this reason that the Jays and Guardians are thought of as amongst the most exciting, young teams in the MLB. With this being said however, let us break down these cores player-by-player with the simplest measures of performance for their 2022 seasons. This narrowly-timed analysis fails to account for past performance, but suffices at a basic level, as these statistics are the most relevant, recent measurables.
#
# ### Jays
#
# - Vladimir Guerrero Jr, 1B:
#     - Age 24
#     - .274/.339/.480 slash
#     - 32 HR 97 RBI 8 SB
#     - 3.7 oWAR -0.7 dWAR
#     - Signed thru 2023, 1 yr/$14.5M (23)
#
# - Bo Bichette, SS:
#     - Age 25
#     - .290/.333/.469
#     - 24 HR 93 RBI 13 SB
#     - 5.4 oWAR	0.8 dWAR
#     - Signed thru 2025, 3 yrs/$33.6M (23-25)
# - Alec Manoah, RHP:
#     - Age 23
#     - 196.2 IP 180 SO 2.24 ERA
#     - 6.0 dWAR
#     - Pre Arb, Rookie Deal
#     - Arb Eligible: 2025   Free Agent: 2028
#
# ### Guardians
#
# - Jose Ramirez, 3B:
#     - Age 30
#     - .280/.355/.514 slash
#     - 29 HR	126 RBI 20 SB
#     - 5.8 oWAR 0.3 dWAR
#     - Signed thru 2028, 7 yrs/$141M (22-28)
#
# - Andres Gimenez, SS:
#     - Age 25
#     - .297/.371/.466
#     - 17 HR 69 RBI 20 SB
#     - 5.6 oWAR	2.4 dWAR
#     - Signed thru 2029, 7 yrs/$106.5M (23-29) & 30 team option
# - Steven Kwan, OF:
#     - Age 25
#     - .298/.373/.400
#     - 6 HR 52 RBI 19 SB
#     - 4 oWAR	1 dWAR
#     -  Pre Arb Rookie Deal
#     - Arb Eligible: 2025    Free Agent: 2028
#
# Overall, it's clear that the Guardians players provided more overall value in the 2022 season. This is furthered by the Guardians suprising run to the ALDS, while the Jays failed to advance to the playoffs. This outperformance is slight, and might not exist if not for Guerrero's down year in 2022. Nevertheless, this needs to be factored into the decision. In particular, Gimenez's season stands out as extraordinary considering his contract situation (rookie deal before signing the above deal in the offseason). As a Met fan, I wonder what could have been if Gimenez acheived this success in Queens.
#
# Even with this new contract considered, there is evidence to say it is an extremely team friendly deal, similarly to underrated superstar Jose Ramirez only making 20m/yr. With these deals being so adventageous relative to player performance and what both players would garner in FA, it is hard to argue against this core being preferrable.
#
# On the other hand, the Jays core has one main advantage: age. The younger relative age of these players
# provides years of immense skill yet to come. Generally, these younger ages comes arbitration years, rookie deals, and lower tier, shorter contracts. This is very much the case for this set of players, as having a perenial Cy Young winner on a minor league contract is invaluable. However, with Bichette and Vlad Jr. due to receive long term deals that would dwarf Gimenez's and Ramirez's, it becomes hard to imagine all players being able to become locked up. This is highlighted in this brief article which seems to indicate that one of these three players will not be prioritized:
# - "However, with five years of team control, the Blue Jays may prioritize negotiations with other members of the young core set to hit free agency sooner. Bo Bichette and Vladimir Guerrero Jr. will reach free agency after the 2025 seasons. By the time Manoah hits free agency after 2027, the current contracts of George Springer, Kevin Gausman, and Chris Bassitt will no longer be on the books." https://www.si.com/mlb/bluejays/news/blue-jays-alek-manoah-extension-talks-2023-offseason
#
# For these reasons, I believe the answer to 'which core is better' is not simple and might be determined by external team factors; for a win now team who might have immense financial capabilities like the Mets Padres or Dodgers, the Jays young talent would probably be preferrable, especially since I am willfully ignoring Vlad Jr.s 2021 MVP caliber year. However, for a more modestly resourced team who is looking to compete year in and year out, the Guardians core with their team-friendly long term deals would benefit more greatly.

# %% [markdown]
# # 3.

# %% [markdown]
# # 4.

# %% [markdown]
# **Suppose Barry Bonds comes out of retirement and is back to his peak 2001 level, but there’s one
# hitch: at his age, he’s only able to hit for one PA per game. He’s currently a free agent, and you
# work for a contending team.**
#
# **How would you quantify his value in a single plate appearance? What ingredients would you
# need to help you calculate this? How could you then determine when you expect him to bat?**
#
# **Next, how would you quantify Bonds’ value to your club? Describe your methodology in detail,
# including any assumptions and information you would need.**

# %% [markdown]
# In this thought experiment, Barry Bonds and his mythical 2001 season (during which he ate his veggies) represent the absolute peak of what is statistically possible for a season.
#
# For this reason, the question could be rephrased to say "how valuable would one at bat of the best player ever be?". Regardless of this

# %% [markdown]
# # 5a.

# %% [markdown]
# ## player_lookup.csv Creation

# %% [markdown]
# Create connection to obtain skeletons of tables including the appropriate primary and foreign keys.

# %%
from sqlalchemy import create_engine
import pandas as pd

db_connection_str = 'mysql+pymysql://root:furcal123@localhost:3306/nats'
db_connection = create_engine(db_connection_str)

player_lookup =  pd.read_sql_table('player_lookup',con= db_connection)

player_lookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   player_id  0 non-null      int64
#  1   name       0 non-null      object
#  2   throws     0 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 0.0+ bytes

# %% [markdown]
# To generate random names to represent players, a name module is imported and top names from multiple heritages are randomly created.

# %%
from names_dataset import NameDataset

names = NameDataset(load_first_names=True,load_last_names=True)

mx_first = names.get_top_names(n = 1000, use_first_names=True,gender = 'M',country_alpha2 = 'MX')
mx_last = names.get_top_names(n = 1000, use_first_names=False,country_alpha2 = 'MX')

us_first = names.get_top_names(n = 1000, use_first_names=True,gender = 'M',country_alpha2 = 'US')
us_last = names.get_top_names(n = 1000, use_first_names=False,country_alpha2 = 'US')

jp_first = names.get_top_names(n = 1000, use_first_names=True,gender = 'M',country_alpha2 = 'JP')
jp_last = names.get_top_names(n = 1000, use_first_names=False,country_alpha2 = 'JP')

# %% [markdown]
# Generate random first-last pairs.

# %%
import itertools
import random
import re

random.seed(11)

def randomize_names(firsts,lasts,num_to_generate,nation_code):
    # cartesian product random choice
    a =random.sample(list(itertools.product(list(firsts[nation_code]['M']),list(lasts[nation_code]))),num_to_generate)
    unpacked = []
    for a_tup in a:
        new = f'{a_tup[0]} {a_tup[1]}'
        # reroll foreign non ascii characters to simplify
        while( bool(re.search(r"[^\x00-\x7F]+", new))):
            new = random.sample(list(itertools.product(list(firsts[nation_code]['M']),list(lasts[nation_code]))),k=1)
            new = f'{new[0][0]} {new[0][1]}'
        unpacked.append(new)
    return unpacked

# %% [markdown]
# The number of players to generate has to mirror the amount of players in this fictional league: mirroring MLB rules 30 teams, of 28 players each, usually 14 pitchers and 14 hitters.

# %%
player_num = 30*28+1
player_lookup['player_id'] = range(1,player_num)

# %%
us_names = randomize_names(us_first,us_last,int(player_num/3),'US')
jp_names = randomize_names(jp_first,jp_last,int(player_num/3),'JP')
mx_names = randomize_names(mx_first,mx_last,int(player_num/3),"MX")

all_names = us_names + jp_names + mx_names
random.shuffle(all_names)

player_lookup['name'] = all_names

# %% [markdown]
# Among pitchers who threw at least 10 innings in 2019,
#
#     174 are left-handed
#     472 are right-handed
#
# That makes ~26% left-handed.

# %%
throws = []
for i in range(1,player_num):
    rand = random.randint(0,9999)
    if(rand < 2600):
        throws.append('L')
    elif(rand >2600):
        throws.append('R')
    else:
        throws.append('S') # switch pitcher 1 in a 10000
        
player_lookup['throws'] = throws

# %%
player_lookup
# Out:
#      player_id             name throws
# 0            1  Hiroaki Teshima      R
# 1            2      Franky Mayo      R
# 2            3    Crispin Roque      L
# 3            4     Paco Vazquez      R
# 4            5  Chava Christian      R
# ..         ...              ...    ...
# 835        836   Logan Bradford      R
# 836        837     Serch Padron      R
# 837        838       Ja Mireles      R
# 838        839      Naito Amano      R
# 839        840   Hidetoshi Kaji      R
#
# [840 rows x 3 columns]

# %% [markdown]
# ## game_lookup.csv Creation

# %% [markdown]
# The Major League Baseball (MLB) season schedule generally consists of 162 games for each of the 30 teams in the American League (AL) and National League (NL), played over approximately six months – a total of 2,430 games.

# %% [markdown]
# Obtain skeleton with primary key `game_id`

# %%
game_lookup = pd.read_sql_table('game_lookup',con= db_connection)

game_lookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   game_id       0 non-null      int64
#  1   game_date     0 non-null      datetime64[ns]
#  2   home_team_id  0 non-null      int64
#  3   away_team_id  0 non-null      int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 0.0+ bytes

# %%
total_games = int(162*30/2)

# %%
game_lookup['game_id'] = range(1,total_games+1)

# %%
# keep track of games played for each team 
games_played_by_team = {i:0 for i in range(1,31)}

# final record (list of 3-tuples)
game_record = []

date_record = pd.date_range(start='3/30/2023', end='10/1/2023').date

# for each date i 
for i in range(0,len(date_record)):
    
    # generate valid opponenets list for each date
    teams_avail_to_play = list(range(1,31))
    
    # for each team j
    for j in range(1,31): 
        
        #  (team can't play itself)
        try:
            teams_avail_to_play.remove(j)
        except:
            continue

        # if team i has played 162, skip to next team
        if (games_played_by_team[j] >161):
            continue

        #generate opponent guess
        try:
            rand= random.choice(teams_avail_to_play) 
        except:
            # empty, no valid opponents (move to next day)
            continue

        # only assert the team to play is valid (team j already taken out)
        assert (rand in teams_avail_to_play)

        # add record of the game, then increment games played for both teams
        game_record.append((date_record[i],j,rand))
        games_played_by_team[j] += 1
        games_played_by_team[rand] +=1
                
        # team rand, played today
        teams_avail_to_play.remove(rand)
        
# assert full list of teams is 162       
assert(all(games == 162 for games in games_played_by_team.values()))

# %%
game_record.sort()

# %%
# fill in to skeleton
game_lookup[['game_date','home_team_id','away_team_id']]= game_record
game_lookup
# Out:
#       game_id   game_date home_team_id away_team_id
# 0           1  2023-03-30            1           17
# 1           2  2023-03-30            2           14
# 2           3  2023-03-30            3            8
# 3           4  2023-03-30            4           24
# 4           5  2023-03-30            5           21
# ...       ...         ...          ...          ...
# 2425     2426  2023-09-07           14           20
# 2426     2427  2023-09-07           15           18
# 2427     2428  2023-09-07           16           17
# 2428     2429  2023-09-07           19           28
# 2429     2430  2023-09-07           21           27
#
# [2430 rows x 4 columns]

# %%
# all teams are represented and have 162 games played
game_lookup.nunique()
# Out:
# game_id         2430
# game_date        162
# home_team_id      29
# away_team_id      29
# dtype: int64

# %% [markdown]
# ## pitches.csv Creation

# %% [markdown]
# Next, to generate the pitches according to the created skeleton

# %%
pitches =  pd.read_sql_table('pitches',con= db_connection)
pitches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   game_id          0 non-null      int64
#  1   pitch_no         0 non-null      int64
#  2   at_bat_no        0 non-null      int64
#  3   pitch_of_at_bat  0 non-null      int64
#  4   inning           0 non-null      int64
#  5   top_inning       0 non-null      int64
#  6   pitcher_id       0 non-null      int64
#  7   batter_id        0 non-null      int64
#  8   velo             0 non-null      float64
# dtypes: float64(1), int64(8)
# memory usage: 0.0+ bytes

# %% [markdown]
# All columns to be integers except velocity, which is a floating point decimal.

# %% [markdown]
# - "Major League Baseball now records information about every pitch thrown in every game of every season. Statistician Jim Albert compiled data about every pitch thrown by 20 starting pitchers during the 2009 MLB season. The data set included the type of pitch thrown (curveball, changeup, slider, etc.) as well as the speed of the ball as it left the pitcher’s hand. A histogram of speeds for all 30,740 four-seam fastballs thrown by these pitchers during the 2009 season is shown below, from which we can see that the speeds of these fastballs follow a Normal model with mean μ = 92.12 mph and a standard deviation of σ = 2.43 mph."

# %% [markdown]
# This is the logic to move forward with for pitch speed selection.

# %%
pitch_record = []
# for each game
for one_game in game_lookup['game_id']:
    
    # assign ID
    game_id = one_game
    
    # account for mismatching parameters (i.e. 0 1 aligned)
    home_no = game_lookup.loc[one_game-1]['home_team_id'] - 1
    away_no = game_lookup.loc[one_game-1]['away_team_id'] - 1
    
    # reset game pitch no and at bat for each new game
    pitch_no = 0
    at_bat_no = 0
    
    # for each half inning (18 in a game)
    for one_half_inning in range(0,18):
        
        # inning is quotient rounded 
        inning = int(one_half_inning/2) + 1
        
        # default to top inning 
        top_inning = 1
        
        # if 1 mod 2 , then bottom inning 
        if((one_half_inning% 2) == 1):
            top_inning = 0
            
        # if top inning, the home pitcher is pitching, randomly assign a pitcher value (30* id + random 0,13 for the 14 pitchers on the roster)
        if(top_inning == 1):
            pitcher_id = 30*home_no + random.randint(0,13)
        # away pitcher is pitching 
        else:
            pitcher_id = 30*away_no + random.randint(0,13)
        # for one at bat
        for one_at_bat in range(0,random.randint(3,10)):
            
            # increment at bat and set at bat pitch counter to 0
            at_bat_no += 1
            pitch_of_at_bat = 0
            
            # assign batter id in a similar way
            if(top_inning == 1):
                batter_id = 30*away_no + random.randint(14,27)
            else:
                batter_id = 30*home_no + random.randint(14,27)
            
            # for each pitch
            for one_pitch in range(0,random.randint(1,8)):
                # increment pitch counter and pitch no of at bat
                pitch_no +=1
                pitch_of_at_bat +=1
                
                # estimate a velo given the previously discussed mean and sd
                velo = round(random.normalvariate( mu= 92.12, sigma=2.43),2)
                
                # append all the counter and relevant info for each pitch
                pitch_record.append((game_id,pitch_no,at_bat_no,pitch_of_at_bat,inning,top_inning,pitcher_id,batter_id,velo))

pitches[pitches.columns] = pitch_record

# %%
# all converted to float as a part of the fill, so just reassign all cols except velo to int without losing data
pitches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1282907 entries, 0 to 1282906
# Data columns (total 9 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   game_id          1282907 non-null  float64
#  1   pitch_no         1282907 non-null  float64
#  2   at_bat_no        1282907 non-null  float64
#  3   pitch_of_at_bat  1282907 non-null  float64
#  4   inning           1282907 non-null  float64
#  5   top_inning       1282907 non-null  float64
#  6   pitcher_id       1282907 non-null  float64
#  7   batter_id        1282907 non-null  float64
#  8   velo             1282907 non-null  float64
# dtypes: float64(9)
# memory usage: 88.1 MB

# %%
pitches[pitches.columns[0:-1]] = pitches[pitches.columns[0:-1]].astype(int)

# %%
pitches.info()
pitches.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1282907 entries, 0 to 1282906
# Data columns (total 9 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   game_id          1282907 non-null  int64
#  1   pitch_no         1282907 non-null  int64
#  2   at_bat_no        1282907 non-null  int64
#  3   pitch_of_at_bat  1282907 non-null  int64
#  4   inning           1282907 non-null  int64
#  5   top_inning       1282907 non-null  int64
#  6   pitcher_id       1282907 non-null  int64
#  7   batter_id        1282907 non-null  int64
#  8   velo             1282907 non-null  float64
# dtypes: float64(1), int64(8)
# memory usage: 88.1 MB
#    game_id  pitch_no  at_bat_no  pitch_of_at_bat  inning  top_inning  \
# 0        1         1          1                1       1           1
# 1        1         2          1                2       1           1
# 2        1         3          2                1       1           1
# ...

# %%
game_lookup.to_csv('game_lookup.csv')
player_lookup.to_csv('player_lookup.csv')
pitches.to_csv('pitches.csv')

# %% [markdown]
# # 5b.

# %%
import datetime

def create_date(split):
    return datetime.date(int(split[0]),int(split[1]),int(split[2]))

def pitcher_summary(player_lookup, game_lookup, pitches, start_date, end_date):
    return_df = pd.DataFrame([])
    
    main = pd.merge(game_lookup, pitches, on='game_id', how='inner')
    main = pd.merge( main,  player_lookup, left_on='pitcher_id', right_on ='player_id', how='inner')
    
    start_date = create_date(start_date.split('-'))
    end_date = create_date(end_date.split('-'))
    
    date_window = main.loc[main['game_date'].between(start_date,end_date,inclusive='both')]

    grouped = date_window.groupby('pitcher_id')
    num_pitches = grouped.count().iloc[:,0]
    ids = num_pitches.index
    name = grouped.max()['name']
    avg_velo =grouped.mean()['velo']
    
    game_count = {}
    for an_id in ids:
        num_games = len(list(date_window.groupby(['pitcher_id','game_id']).count().loc[an_id].index))
        game_count[an_id] = num_games
    temp = {'name':name,'game_count':pd.Series(game_count),'num_pitches':num_pitches,'avg_velo':avg_velo}
    return_df = pd.DataFrame(temp)
    return return_df

# %%
pitcher_summary = pitcher_summary(player_lookup,game_lookup,pitches,'2023-04-01','2023-05-01')

# %%
pitcher_summary
# Out:
#                 name  game_count  num_pitches   avg_velo
# 1    Hiroaki Teshima          14          670  92.091104
# 2        Franky Mayo          15          593  91.950675
# 3      Crispin Roque          10          470  92.120851
# 4       Paco Vazquez          18          952  92.221618
# 5    Chava Christian          11          416  92.204712
# ..               ...         ...          ...        ...
# 820      Taro Tokuda          15          598  92.051421
# 821    Eber Espinosa          17          691  92.169768
# 822        Ej Nicole          17          680  92.146338
# 823        Brian Rmz          12          519  92.226089
# 840   Hidetoshi Kaji          12          480  92.229271
#
# [392 rows x 4 columns]

# %% [markdown]
# # 5c.

# %% [markdown]
# Write a function that takes an end_date as an input which produces a dataframe which gives a
# matrix of pitch count by pitcher and date from (end_date – 6 days) up to and including
# end_date, where the rows are pitchers and the columns are the days. Only include pitchers who
# pitched for team_id = 120. Add total pitch counts from the last 3 days and from the last 7 days.
# Add a flag that indicates whether a reliever has had a heavy recent workload (just pitched in
# back-to-back games, or on three of the previous four days)

# %%
import numpy as np

def pitcher_matrix(team_id,end_date):
    
    # set up row and col labels (useful for entry later)
    team_id = team_id
    end_date = create_date(end_date.split('-'))
    six_days_earlier = end_date - pd.Timedelta(days=6)
    date_range = pd.date_range(six_days_earlier,end_date).date
    team_pitcher_ids = pitcher_summary.loc[30*(team_id - 1):30*(team_id - 1)+14,:]['name']

    # rows are all pitchers, cols are dates
    return_df = pd.DataFrame(index =team_pitcher_ids, columns=date_range)



    # merge on ids to get info
    main = pd.merge(game_lookup, pitches, on='game_id', how='inner')
    main = pd.merge( main,  player_lookup, left_on='pitcher_id', right_on ='player_id', how='inner')
    
    # filter to date window
    date_window = main.loc[main['game_date'].between(six_days_earlier,end_date,inclusive='both')]

    # all away games played for team, with relevant inning bottoms aka, away team pitching
    away_games_played = date_window.loc[(date_window['away_team_id'] == team_id)]
    inning_bottoms = away_games_played.loc[away_games_played['top_inning'] == 0]
    
    # group by the date and name (result : 3/31/2023 Pitcher 1 | 12 pitches
    #                                                Pitcher 2 | 30 pitches
    #                                                etc. )
    per_game_data = inning_bottoms.groupby(['game_date','name']).count()

    # game date, name, pitches with index reset
    relevant_data = per_game_data.iloc[:,0:1].reset_index()

    # read into dateframe 
    for name in return_df.index:
        temp = relevant_data.loc[relevant_data['name'] == name]
        for one_game in temp.index:
             return_df.loc[temp.loc[one_game,'name'],temp.loc[one_game,'game_date']] = temp.loc[one_game,'game_id']

    # repeat for home team (top inning pitcher pitches)
    home_games_played = date_window.loc[(date_window['home_team_id'] == team_id)]
    inning_tops = home_games_played.loc[home_games_played['top_inning'] == 1]
    per_game_data = inning_tops.groupby(['game_date','name']).count()
    relevant_data = per_game_data.iloc[:,0:1].reset_index()
    for name in return_df.index:
        temp = relevant_data.loc[relevant_data['name'] == name]
        for one_game in temp.index:
             return_df.loc[temp.loc[one_game,'name'],temp.loc[one_game,'game_date']] = temp.loc[one_game,'game_id']          
   
    # fill in NaN with 0
    return_df = return_df.fillna(0)  
    
    # create sum columns
    return_df['Last 3 Days'] =return_df.iloc[:,[-1,-2,-3]].sum(axis = 1)
    return_df['Last 7 Days'] = return_df.sum(axis = 1)
    
    # add a flag for availability
    back_to_back = ((return_df.iloc[:,-3]!= 0) & (return_df.iloc[:,-4]!= 0)) 
    # only case need to account for (due to above already flagging) is pitch, pitch, rest, pitch and p,p,p,r
    three_of_four = ((return_df.iloc[:,-3] != 0) & (return_df.iloc[:,-4] == 0) & (return_df.iloc[:,-5] != 0) & (return_df.iloc[:,-6] != 0)) |         ((return_df.iloc[:,-3] == 0) & (return_df.iloc[:,-4] != 0) & (return_df.iloc[:,-5] != 0) & (return_df.iloc[:,-6] != 0))
    return_df['unavailable'] = np.where(back_to_back |three_of_four ,1,0)

    return return_df

# %%
pitcher_matrix(28,'2023-05-15')
# Out:
#                    2023-05-09  2023-05-10  2023-05-11  2023-05-12  2023-05-13  \
# name
# Ricardo West               25           0           0           6           0
# Aurelio Rendon              0           0           0           0           0
# Patricio Hinojosa           0          54           0          10          18
# Bernabe Aldana              0          26          38           0           0
# Hernan Mateo               28          30          45          62          49
# Sergey Mena                48           0          14           0           0
# Kenichi Nakama              0           0         149           0           0
# Kiko Godoy                  0           0          24          13          24
# Oso Fernandez              50           0           0          15          35
# Jose Roberto Gil            8          39           0          40           0
# Taro Tokuda                30           0           0           0          47
# ...
